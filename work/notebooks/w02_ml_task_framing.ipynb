# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mariamemad975/FlyRank_ML/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# Ranking
#
#
# I frame my lane as a ranking problem as the goal is to order pages by their priority for content review. The model would use observed page and search performance signals to rank pages from higher to lower content opportunity. This ranking supports a content manager who needs to decide which pages to review first, rather than making an automatic decision.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# There is no directly observed outcome in the starter data showing whether a page improved after a content refresh. Therefore, I would use a defined content opportunity proxy rather than a causal target. The proxy would combine observed signals such as search visibility, CTR, and average position to identify pages that appear worth reviewing. The proxy represents prioritization opportunity, not guaranteed improvement after refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# Precision, measures how many of the top n pages selected by the ranking are relevant according to the defined opportunity proxy. This matches the real decision because a content manager is likely to review only a limited number of pages first. A higher Precision means the ranking puts more high priority pages near the top.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
else:
    # find the repo root from wherever this kernel started
    while not os.path.isdir("data/raw") and os.getcwd() != "/":
        os.chdir("..")

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"
print("Starter data found. You're ready.")
# Out:
# Working dir: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter
# Starter data found. You're ready.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
lane_columns = [
    "impressions_90d",
    "clicks_90d",
    "ctr",
    "avg_position",
    "search_volume",
    "content_age_days",
    "days_since_last_update",
    "trend_pct"
]

lane_df = df[lane_columns].copy()

lane_df.head()
# Out:
#    impressions_90d  clicks_90d   ctr  avg_position  search_volume  \
# 0             3803          29  0.76          10.6           10.0
# 1            15320           7  0.05          20.3           90.0
# 2            12581          11  0.09          36.5            0.0
# 3            11751          58  0.49           6.2           10.0
# 4            19140          24  0.13          44.0            0.0
#
#    content_age_days  days_since_last_update  trend_pct
# 0               187                      20      -41.4
# 1               445                      25      -57.7
# 2               141                      20      -60.9
# 3               463                      22      -13.8
# 4               263                      14      -34.7

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule like “refresh pages with CTR” uses only one signal and may miss important differences between pages. A ranking model can combine multiple signals, such as impressions, search demand, average position, trends, and content freshness, to prioritize pages more effectively. ML is useful if it performs better than a simple fixed-rule baseline.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
