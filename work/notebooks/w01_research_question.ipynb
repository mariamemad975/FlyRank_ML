# %% [markdown]
# <a href="https://colab.research.google.com/github/mariamemad975/FlyRank_ML/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mariamemad975/FlyRank_ML/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane 2: Refresh / Content Opportunity Scoring
#
# I chose this lane because it focuses on helping teams decide which pages should be reviewed first to improve search performance. Instead of trying to explain Google ranking algorithm, I want to build a transparent decision support system that ranks pages for refresh based on observed search performance. This lane combines data analysis and machine learning.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# My research question is: Which pages should be reviewed first for refresh, expansion, protection, pruning, or monitoring? This work supports the decision of a content manager who must choose which pages to review first. A poor recommendation could waste time updating pages with little opportunity for improvement while delaying work on pages that may have greater business value. The goal is to provide decision-support that helps prioritize review, not to make automatic decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset contains 30,000 rows and 44 columns. The average of CTR is 0.51%, and the median search position is 10.8. These numbers show meaningful variation in search performance, making the dataset suitable for identifying pages that may benefit from content refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
else:
    # find the repo root from wherever this kernel started
    while not os.path.isdir("data/raw") and os.getcwd() != "/":
        os.chdir("..")

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"
print("Starter data found. You're ready.")
# Out:
# Working dir: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter
# Starter data found. You're ready.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
# Out:
# Rows: 30000
# Columns: 44

# %%
print("Numeric columns:")
print(df.select_dtypes(include="number").columns.tolist())
# Out:
# Numeric columns:
# ['search_volume', 'competition', 'cpc', 'word_count', 'char_count', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier_order', 'days_since_last_update', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'trend_pct']

# %%
print("Summary:")
print(df.describe().T)
# Out:
# Summary:
#                           count          mean           std    min      25%  \
# search_volume           27532.0    158.882391   1518.270825    0.0      0.0
# competition             27532.0      0.146954      0.285241    0.0      0.0
# cpc                     27532.0      0.485342      2.101560    0.0      0.0
# word_count              22301.0   3107.760325   1452.382598    8.0   2413.0
# char_count              22301.0  20665.277835  10115.344042   40.0  15644.0
# impressions_90d         30000.0   5200.366300  16838.019547    1.0     81.0
# clicks_90d              30000.0     16.097333     75.076958    0.0      0.0
# pageviews_90d           30000.0     49.942467    152.101430    0.0      2.0
# sessions_90d            30000.0     37.066633    107.069131    1.0      2.0
# users_90d               30000.0     35.937700    103.748185    1.0      2.0
# engaged_sessions_90d    30000.0      0.991933      4.359576    0.0      0.0
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# Will identify observed patterns in historical search performance and provide decision for prioritizing content review. The results may show directional relationships between search metrics and refresh opportunities, but they donot prove that refreshing a page will improve ranking or traffic. This work cannot predict Googles ranking algorithm or establish cause and effect relationships, and its recommendations should be combined with human judgment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
